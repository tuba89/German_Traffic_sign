# %%
signnames_p = "/content/drive/MyDrive/TraficData/signnames.csv"
test_p = "/content/drive/MyDrive/TraficData/test.p"
train_p = "/content/drive/MyDrive/TraficData/train.p"
valid_p = "/content/drive/MyDrive/TraficData/valid.p"

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import keras

# %%
import tensorflow as tf

# %%
#title Run Me Please
# !pip -q install pydot_ng
# !pip -q install graphviz
# !apt install graphviz > /dev/null
# Out:
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.

# %%
from __future__ import absolute_import, division, print_function
import warnings
warnings.filterwarnings("ignore")

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython import display
# %matplotlib inline
from tensorflow import keras
# try:
#   tf.enable_eager_execution()
#   print('Running in Eager mode.')
# except ValueError:
#   print('Already running in Eager mode')

# %%
from builtins import range, input
from keras.layers import Input, Lambda, Dense, Flatten, Dropout, GlobalAveragePooling2D
from keras.models import Model
from keras.applications.vgg16 import VGG16
from keras.applications import vgg19
from tensorflow.keras.applications.resnet50 import ResNet50

# %%
# from keras.applications.inception_v3 import inception_v3
from keras.applications.inception_v3 import InceptionV3

# %%
from keras.applications.vgg16 import preprocess_input
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.utils.vis_utils import plot_model
# from tensorflow.contrib.layers import Flatten

from sklearn.metrics import confusion_matrix
import numpy as np
import matplotlib.pyplot as plt
from time import time
import pickle
from sklearn.utils import shuffle

# Feel free to import more packages
import pandas as pd
import random
import seaborn as sns
# from sklearn.metrics import confusion_matrix

# %% [markdown]
# # Step 0: Load The Data

# %%
# Load pickled data

# TODO: Fill this in based on where you saved the training and testing data
# If you have a folder in your Drive named traffic-signs-data you do so, else change directory

with open(train_p, mode='rb') as f:
    train = pickle.load(f)
with open(valid_p, mode='rb') as f:
    valid = pickle.load(f)
with open(test_p, mode='rb') as f:
    test = pickle.load(f)

# %% [markdown]
# ---
#
# ## Step 1: Dataset Summary & Exploration
#
# The pickled data is a dictionary with 4 key/value pairs:
#
# - `'features'` is a 4D array containing raw pixel data of the traffic sign images, (num examples, width, height, channels).
# - `'labels'` is a 1D array containing the label/class id of the traffic sign. The file `signnames.csv` contains id -> name mappings for each id.
# - `'sizes'` is a list containing tuples, (width, height) representing the original width and height the image.
# - `'coords'` is a list containing tuples, (x1, y1, x2, y2) representing coordinates of a bounding box around the sign in the image. **THESE COORDINATES ASSUME THE ORIGINAL IMAGE. THE PICKLED DATA CONTAINS RESIZED VERSIONS (32 by 32) OF THESE IMAGES**
#
# Complete the basic data summary below. Use python, numpy and/or pandas methods to calculate the data summary rather than hard coding the results. For example, the [pandas shape method](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.shape.html) might be useful for calculating some of the summary results.

# %%
# Please complete None with your code
#-------------------------------------------------------------------------
signs = []
signnames = pd.read_csv(signnames_p, delimiter=',', header=0)
for row in range(signnames.shape[0]):
     signs.append(signnames.iloc[row, 1])

# %%
signnames.head()
# Out:
#    ClassId              SignName
# 0        0  Speed limit (20km/h)
# 1        1  Speed limit (30km/h)
# 2        2  Speed limit (50km/h)
# 3        3  Speed limit (60km/h)
# 4        4  Speed limit (70km/h)

# %%
signnames.items
# Out:
# <bound method DataFrame.items of     ClassId                                           SignName
# 0         0                               Speed limit (20km/h)
# 1         1                               Speed limit (30km/h)
# 2         2                               Speed limit (50km/h)
# 3         3                               Speed limit (60km/h)
# 4         4                               Speed limit (70km/h)
# 5         5                               Speed limit (80km/h)
# 6         6                        End of speed limit (80km/h)
# 7         7                              Speed limit (100km/h)
# 8         8                              Speed limit (120km/h)
# 9         9                                         No passing
# 10       10       No passing for vechiles over 3.5 metric tons
# 11       11              Right-of-way at the next intersection
# 12       12                                      Priority road
# 13       13                                              Yield
# 14       14                                               Stop
# 15       15                                        No vechiles
# 16       16           Vechiles over 3.5 metric tons prohibited
# 17       17                                           No entry
# 18       18                                    General caution
# 19       19                        Dangerous curve to the left
# 20       20                       Dangerous curve to the right
# 21       21                                       Double curve
# 22       22                                         Bumpy road
# 23       23                                      Slippery road
# 24       24                          Road narrows on the right
# 25       25                                          Road work
# 26       26                                    Traffic signals
# 27       27                                        Pedestrians
# 28       28                                  Children crossing
# 29       29                                  Bicycles crossing
# 30       30                                 Beware of ice/snow
# 31       31                              Wild animals crossing
# 32       32                End of all speed and passing limits
# 33       33                                   Turn right ahead
# 34       34                                    Turn left ahead
# 35       35                                         Ahead only
# 36       36                               Go straight or right
# 37       37                                Go straight or left
# 38       38                                         Keep right
# 39       39                                          Keep left
# 40       40                               Roundabout mandatory
# 41       41                                  End of no passing
# 42       42  End of no passing by vechiles over 3.5 metric ...>

# %%
signs[:5]
# Out:
# ['Speed limit (20km/h)',
#  'Speed limit (30km/h)',
#  'Speed limit (50km/h)',
#  'Speed limit (60km/h)',
#  'Speed limit (70km/h)']

# %%
print(train.keys())
print(test.keys())
print(valid.keys())
# Out:
# dict_keys(['coords', 'labels', 'features', 'sizes'])
# dict_keys(['sizes', 'coords', 'features', 'labels'])
# dict_keys(['coords', 'labels', 'features', 'sizes'])

# %%
X_train, y_train = train['features'], train['labels']
X_valid, y_valid = valid['features'], valid['labels']
X_test, y_test = test['features'], test['labels']

# %%
print("training", X_train.shape)
print("validation", X_valid.shape)
print("testing", X_test.shape)
print("training_class", y_train.shape)
print("validation_class", y_valid.shape)
print("testing_class", y_test.shape)
print(type(y_test))
# Out:
# training (34799, 32, 32, 3)
# validation (4410, 32, 32, 3)
# testing (12630, 32, 32, 3)
# training_class (34799,)
# validation_class (4410,)
# testing_class (12630,)
# <class 'numpy.ndarray'>

# %%
X_test[0].shape
x = np.unique(train["labels"])
# unique, counts = np.unique(y_train, return_counts=True)
# # print(np.asarray((unique, counts)).T)
# np.size(x)
x
np.size(x)
# Out:
# 43

# %% [markdown]
# ### Provide a Basic Summary of the Data Set Using Python, Numpy and/or Pandas

# %%
# Please complete None with your code
#-------------------------------------------------------------------------
#  Number of training examples
n_train = X_train.shape[0]

# Number of validation examples
n_validation = X_valid.shape[0]

# Number of test examples.
n_test = X_test.shape[0]

#  What's the shape of a traffic sign image?
image_shape = X_test[0].shape

#  How many unique classes/labels there are in the dataset.
unique_label = np.unique(test["labels"])
n_classes = len(unique_label)


print("Number of training examples =", n_train)
print("Number of testing examples =", n_test)
print("Number of valid examples =", n_validation)
print("Image data shape =", image_shape)
print("Number of classes =", n_classes)

# output
# Number of training examples = 34799
# Number of testing examples = 12630
# Number of valid examples = 4410
# Image data shape = (32, 32, 3)
# Number of classes = 43
# Out:
# Number of training examples = 34799
# Number of testing examples = 12630
# Number of valid examples = 4410
# Image data shape = (32, 32, 3)
# Number of classes = 43

# %% [markdown]
# ### Include an exploratory visualization of the dataset

# %% [markdown]
# Visualize the German Traffic Signs Dataset using the pickled file(s). This is open ended, suggestions include: plotting traffic sign images, plotting the count of each sign, etc.
#
# The [Matplotlib](http://matplotlib.org/) [examples](http://matplotlib.org/examples/index.html) and [gallery](http://matplotlib.org/gallery.html) pages are a great resource for doing visualizations in Python.
#
# **NOTE:** It's recommended you start with something simple first. If you wish to do more, come back to it after you've completed the rest of the sections. It can be interesting to look at the distribution of classes in the training, validation and test set. Is the distribution the same? Are there more examples of some classes than others?

# %%
### Data exploration visualization code goes here.
def show_images(X,Y,r,c):
  fig, axs = plt.subplots(r,c, figsize=(15, 6))
  fig.subplots_adjust(hspace = .2, wspace=.001)
  axs = axs.ravel()
  for i in range(10): # if rows = 2 and columns = 5 i should take 10 values
      index = random.randint(0, len(X))
      image = X[index]
      axs[i].axis('off')
      axs[i].imshow(image)
      axs[i].set_title(Y[index], fontsize=16, c="#E2062C")
  plt.show() 

# show image of 10 random data points
rows = 1
columns = 10
# show_images (None)
show_images(X_train,y_train,rows, columns)
show_images(X_test,y_test,rows, columns)
show_images(X_valid,y_valid,rows, columns)

# %%
# %matplotlib inline
plt.figure(figsize=(20,5))

item, count = np.unique(y_train, return_counts=True)
#names is a list of traffic signs, Remember that we already have a list : signs
names = signs
y_pos = np.arange(len(names))
plt.bar(item, count, alpha=0.6, color=['#008B8B', '#177245', 'green', '#228B22', '#00FF00'] )

plt.xticks(y_pos, names, fontsize=13, c="#007800", rotation=90)

plt.grid(c="w")
plt.show()

# %%
# %matplotlib inline
plt.figure(figsize=(20,5))
item, count = np.unique(y_test, return_counts=True)
item1, count1 = np.unique(y_valid, return_counts=True)


y_pos = np.arange(len(signs))
plt.bar(item, count, alpha=0.6, color = (0.07,0.03,0.53), label="Validation Data" )

plt.bar(item1, count1, alpha=0.6, color = (0.3,0.73,0.09), label="Train Data" )

plt.xticks(y_pos, signs, fontsize=13, rotation=90)
plt.legend()
plt.grid(c="w")
plt.show()

# %% [markdown]
# ----
#
# ## Step 2: Design and Test a Model Architecture
#
# Design and implement a deep learning model that learns to recognize traffic signs. Train and test your model on the [German Traffic Sign Dataset](http://benchmark.ini.rub.de/?section=gtsrb&subsection=dataset).
#
# The LeNet-5 implementation shown in the [classroom](https://classroom.udacity.com/nanodegrees/nd013/parts/fbf77062-5703-404e-b60c-95b78b2f3f9e/modules/6df7ae49-c61c-4bb2-a23e-6527e69209ec/lessons/601ae704-1035-4287-8b11-e2c2716217ad/concepts/d4aca031-508f-4e0b-b493-e7b706120f81) at the end of the CNN lesson is a solid starting point. You'll have to change the number of classes and possibly the preprocessing, but aside from that it's plug and play!
#
# With the LeNet-5 solution from the lecture, you should expect a validation set accuracy of about 0.89. To meet specifications, the validation set accuracy will need to be at least 0.93. It is possible to get an even higher accuracy, but 0.93 is the minimum for a successful project submission.
#
# There are various aspects to consider when thinking about this problem:
#
# - Neural network architecture (is the network over or underfitting?)
# - Play around preprocessing techniques (normalization, rgb to grayscale, etc)
# - Number of examples per label (some have more than others).
# - Generate fake data.
#
# Here is an example of a [published baseline model on this problem](http://yann.lecun.com/exdb/publis/pdf/sermanet-ijcnn-11.pdf). It's not required to be familiar with the approach used in the paper but, it's good practice to try to read papers like these.

# %% [markdown]
# ### Pre-process the Data Set (normalization, grayscale, etc.)

# %% [markdown]
# Minimally, the image data should be normalized so that the data has mean zero and equal variance. For image data, `(pixel - 128)/ 128` is a quick way to approximately normalize the data and can be used in this project.
#
# Other pre-processing steps are optional. You can try different techniques to see if it improves performance.
#
# Use the code cell (or multiple code cells, if necessary) to implement the first step of your project.

# %%
# gray scale
X_test_gry = np.sum(X_test/3, axis=3, keepdims=True)
X_train_gry = np.sum(X_train/3, axis=3, keepdims=True)
X_valid_gry = np.sum(X_valid/3, axis=3, keepdims=True)

# %%
print('Colored:', X_train.shape)
print('Grayscale:', X_train_gry.shape)
# Out:
# Colored: (34799, 32, 32, 3)
# Grayscale: (34799, 32, 32, 1)

# %%
print(X_test_gry[1][0][:3])
X_test_gry.dtype
# Out:
# [[63.33333333]
#  [76.66666667]
#  [78.66666667]]
# dtype('float64')

# %%
# normalization Here 
 
X_test_norm = (X_test_gry - 128)/ 128
X_train_norm = (X_train_gry - 128)/ 128
X_valid_norm =(X_valid_gry - 128)/ 128

# %%
print('Normal:', X_test_gry[1][0][:3])
print('Scaled:', X_test_norm[1][0][:3], "between -1 & 1")
# Out:
# Normal: [[63.33333333]
#  [76.66666667]
#  [78.66666667]]
# Scaled: [[-0.50520833]
#  [-0.40104167]
#  [-0.38541667]] between -1 & 1

# %%
from sklearn.utils import shuffle

X_train_norm, y_train = shuffle(X_train_norm, y_train)

# %%
import cv2

def random_translate(img):
    rows,cols,_ = img.shape
    
    # allow translation up to px pixels in x and y directions
    px = 2
    dx,dy = np.random.randint(-px,px,2)

    M = np.float32([[1,0,dx],[0,1,dy]])
    dst = cv2.warpAffine(img,M,(cols,rows))
    
    dst = dst[:,:,np.newaxis]
    
    return dst

# %%
# visualize
# %matplotlib inline
test_img = X_train_norm[25]

test_dst = random_translate(test_img)

fig, axs = plt.subplots(1,2, figsize=(10, 3))
# show original image before translation
axs[0].imshow(test_img.squeeze())
axs[0].set_title('Original')
# show with translation
axs[1].imshow(test_dst.squeeze())
axs[1].patch.set_edgecolor('#00A86B')  
axs[1].patch.set_linewidth('5') 
axs[1].set_title('Translated')

print('shape in/out:', test_img.shape, test_dst.shape)
# Out:
# shape in/out: (32, 32, 1) (32, 32, 1)

# %% [markdown]
# Next cells should be useful for data augmentation

# %%
def random_scaling(img):   
    rows,cols,_ = img.shape

    # transform limits
    px = np.random.randint(-2,2)

    # ending locations
    pts1 = np.float32([[px,px],
                       [rows-px,px],
                       [px,cols-px],
                       [rows-px,cols-px]])

    # starting locations (4 corners)
    pts2 = np.float32([[0,0],
                       [rows,0],
                       [0,cols],
                       [rows,cols]])

    M = cv2.getPerspectiveTransform(pts1,pts2)

    dst = cv2.warpPerspective(img,M,(rows,cols))
    
    dst = dst[:,:,np.newaxis]
    
    return dst

# %%
# visualize scaling
test_img = X_train_norm[25]

test_dst = random_scaling(test_img)

fig, axs = plt.subplots(1,2, figsize=(10, 3))
# show original image before translation
axs[0].imshow(test_img.squeeze())
axs[0].set_title('Original')
# show with translation
axs[1].imshow(test_dst.squeeze())
axs[1].patch.set_edgecolor('#00A86B')  
axs[1].patch.set_linewidth('5') 
axs[1].set_title('Scaled')

print('shape in/out:', test_img.shape, test_dst.shape)
# Out:
# shape in/out: (32, 32, 1) (32, 32, 1)

# %%
def random_warp(img):
    
    rows,cols,_ = img.shape

    # random scaling coefficients
    rndx = np.random.rand(3) - 0.5
    rndx *= cols * 0.06   # this coefficient determines the degree of warping
    rndy = np.random.rand(3) - 0.5
    rndy *= rows * 0.06

    # 3 starting points for transform, 1/4 way from edges
    x1 = cols / 4
    x2 = 3 * cols / 4
    y1 = rows / 4
    y2 = 3 * rows / 4

    pts1 = np.float32([[y1,x1],
                       [y2,x1],
                       [y1,x2]])
    pts2 = np.float32([[y1+rndy[0],x1+rndx[0]],
                       [y2+rndy[1],x1+rndx[1]],
                       [y1+rndy[2],x2+rndx[2]]])

    M = cv2.getAffineTransform(pts1,pts2)

    dst = cv2.warpAffine(img,M,(cols,rows))
    
    dst = dst[:,:,np.newaxis]
    
    return dst

# %%
# visualize image after deforming it 
test_img = X_train_norm[25]

test_dst = random_warp(test_img)

fig, axs = plt.subplots(1,2, figsize=(10, 3))
# show original image before translation
axs[0].imshow(test_img.squeeze())
axs[0].set_title('Original')
# show with translation
axs[1].imshow(test_dst.squeeze())
axs[1].patch.set_edgecolor('#00A86B')  
axs[1].patch.set_linewidth('5') 
axs[1].set_title('Twisted')

print('shape in/out:', test_img.shape, test_dst.shape)
# Out:
# shape in/out: (32, 32, 1) (32, 32, 1)

# %%
def random_brightness(img):
    shifted = img + 1.0   # shift to (0,2) range
    img_max_value = max(shifted.flatten())
    max_coef = 2.0/img_max_value
    min_coef = max_coef - 0.1
    coef = np.random.uniform(min_coef, max_coef)
    dst = shifted * coef - 1.0
    return dst

# %%
# visualize image after adjusting the brightness 
test_img = X_train_norm[25]

test_dst = random_brightness(test_img)

fig, axs = plt.subplots(1,2, figsize=(10, 3))
# show original image before translation
axs[0].imshow(test_img.squeeze())
axs[0].set_title('Original')
# show with translation
axs[1].imshow(test_dst.squeeze())
axs[1].patch.set_edgecolor('#00A86B')  
axs[1].patch.set_linewidth('5') 
axs[1].set_title('Adjusted')

print('shape in/out:', test_img.shape, test_dst.shape)
# Out:
# shape in/out: (32, 32, 1) (32, 32, 1)

# %%
# exploratory of the data
from collections import Counter
# create a dict that contain the count of each class 
counter = Counter(y_train)
#convert the values of the dict to list
counter_list = list(counter.values())
# calculate the mean, and get the result as integer
mean = int(np.mean(counter_list)) # 809
# get the min value
min_val = np.min(counter_list) # 180
# get the max value
max_val = np.max(counter_list) # 2010
print(f'Train samples in each class:\n\tThe mean= {mean}.\n\tThe min value= {min_val}.\n\tThe maximum= {max_val}.')
# Out:
# Train samples in each class:
# 	The mean= 809.
# 	The min value= 180.
# 	The maximum= 2010.

# %%
# Helper, transofrm a numeric label into the corresponding string
def getNameByLable(label):
    return signnames.loc[label].SignName
getNameByLable(42)
# Out:
# 'End of no passing by vechiles over 3.5 metric tons'

# %%
# exploratory of the data, most common and most not common

print(" Common 10 Samples :\n","*"*17)
for element in counter.most_common(10):
    print("'{}'".format(getNameByLable(element[0])), 'Train sample : {}'.format(element[1]))

# explore the rare samples
# Sort the dictionary counter and get the last 10 items(which mean the min values)
print("-"*50)
print("-"*50)
print(" Rare 10 Samples :\n","*"*15)
for element in sorted(counter.items(),key=lambda x: x[1])[:10]:
    print("'{}'".format(getNameByLable(element[0])), 'Train sample : {}'.format(element[1]))
# Out:
#  Common 10 Samples :
#  *****************
# 'Speed limit (50km/h)' Train sample : 2010
# 'Speed limit (30km/h)' Train sample : 1980
# 'Yield' Train sample : 1920
# 'Priority road' Train sample : 1890
# 'Keep right' Train sample : 1860
# 'No passing for vechiles over 3.5 metric tons' Train sample : 1800
# 'Speed limit (70km/h)' Train sample : 1770
# 'Speed limit (80km/h)' Train sample : 1650
# 'Road work' Train sample : 1350
# 'No passing' Train sample : 1320
# --------------------------------------------------
# --------------------------------------------------
#  Rare 10 Samples :
#  ***************
# 'Dangerous curve to the left' Train sample : 180
# 'Go straight or left' Train sample : 180
# 'Speed limit (20km/h)' Train sample : 180
# 'Pedestrians' Train sample : 210
# 'End of all speed and passing limits' Train sample : 210
# 'End of no passing by vechiles over 3.5 metric tons' Train sample : 210
# 'End of no passing' Train sample : 210
# 'Road narrows on the right' Train sample : 240
# 'Bicycles crossing' Train sample : 240
# 'Keep left' Train sample : 270

# %%
print(np.bincount(y_train))
print("minimum samples for any label:", min(np.bincount(y_train)))
# Out:
# [ 180 1980 2010 1260 1770 1650  360 1290 1260 1320 1800 1170 1890 1920
#   690  540  360  990 1080  180  300  270  330  450  240 1350  540  210
#   480  240  390  690  210  599  360 1080  330  180 1860  270  300  210
#   210]
# minimum samples for any label: 180

# %%
# the data is imbalanced we need data augmentation
print('X, y shapes:', X_train_norm.shape, y_train.shape)
# Out:
# X, y shapes: (34799, 32, 32, 1) (34799,)

# %%
# Data augmentation 
# This may take too much time...
# i've set 2000 as a minimum number of images for each class
# if u don't already have a file containing generated Data, Run ME please
# --------------------------!!!!-----------------------------------------

input_indices = []
output_indices = []

for class_n in range(n_classes):
    class_indices = np.where(y_train == class_n)
    n_samples = len(class_indices[0])
    if n_samples < 2000:
        for i in range(2000 - n_samples):
            input_indices.append(class_indices[0][i%n_samples])
            output_indices.append(X_train_norm.shape[0])
            new_img = X_train_norm[class_indices[0][i % n_samples]]
            new_img = random_translate(random_scaling(random_warp(random_brightness(new_img))))
            X_train_norm = np.concatenate((X_train_norm, [new_img]), axis=0)
            y_train = np.concatenate((y_train, [class_n]), axis=0)

# %%
data_file = "X_train_norm.p"
pickle.dump({"images":X_train_norm,"labels":y_train},open(data_file,"wb"),protocol=4)

# %%
# if u do have a file that contains new_train data RUN ME
with open("X_train_norm.p","rb") as f:
    data = pickle.load(f)
new_X_train, y_train = data["images"],data["labels"]

# %%
from sklearn.model_selection import train_test_split

X_train, X_validation, y_train, y_validation = train_test_split(new_X_train, y_train, 
                                                                test_size=0.20, random_state=42)

print("Old X_train size:",len(X_train_norm))
print("New X_train size:",len(X_train))
print("X_validation size:",len(X_validation))
# Out:
# Old X_train size: 34799
# New X_train size: 27839
# X_validation size: 6960

# %%
X_train.shape
# Out:
# (27839, 32, 32, 1)

# %%
tf.config.run_functions_eagerly(True)

# %%
tf.data.experimental.enable_debug_mode()

# %% [markdown]
# ##  Micronet pretraind model

# %%
from tensorflow.keras.optimizers import Adam, SGD, Nadam
import tensorflow.keras.layers as kl
from tensorflow.keras.regularizers import l2

# %%
IMG_SIZE = 32

l2_reg_rate = 1e-5  # 0.00001
eps = 1e-7         # 0.0000001
NUM_CLASSES = 43


def get_micronet():
    input_ = kl.Input(shape=(IMG_SIZE,IMG_SIZE,1), name='data')
    # 1-part
    x = kl.Conv2D(filters=1, kernel_size=(1,1), padding='same', kernel_regularizer=l2(l2_reg_rate))(input_)
    x = kl.BatchNormalization(epsilon=eps)(x)
    x = kl.ReLU()(x)
    # 2-part
    x = kl.Conv2D(filters=29, kernel_size=(5,5), kernel_regularizer=l2(l2_reg_rate))(x)
    x = kl.BatchNormalization(epsilon=eps)(x)
    x = kl.ReLU()(x)
    x = kl.MaxPooling2D(pool_size=3, strides=2)(x)
    # 3-part
    x = kl.Conv2D(filters=59, kernel_size=(3,3), padding='same', kernel_regularizer=l2(l2_reg_rate))(x)
    x = kl.BatchNormalization(epsilon=eps)(x)
    x = kl.ReLU()(x)
    x = kl.MaxPooling2D(pool_size=3, strides=2)(x)
    # 4-part
    x = kl.Conv2D(filters=74, kernel_size=(3,3), padding='same', kernel_regularizer=l2(l2_reg_rate))(x)
    x = kl.BatchNormalization(epsilon=eps)(x)
    x = kl.ReLU()(x)
    x = kl.MaxPooling2D(pool_size=3, strides=2)(x)
    # 5-part
    x = kl.Flatten()(x)
    x = kl.Dense(300, kernel_regularizer=l2(l2_reg_rate))(x)
    x = kl.BatchNormalization(epsilon=eps)(x)
    x = kl.ReLU()(x)
    x = kl.Dense(300)(x)
    x = kl.ReLU()(x)
    x = kl.Dense(NUM_CLASSES)(x)
    x = kl.Softmax()(x)
    return Model(inputs=input_, outputs=x)

# %%
model = get_micronet()

# %%
def create_lr_decay(decay_step_size, lr_decay_rate):
    def lr_decay(epoch, lr):
        if epoch % decay_step_size == 0:
            lr = lr * lr_decay_rate
        return lr
    return lr_decay

lr = 0.0007
lr_decay = create_lr_decay(decay_step_size=2, lr_decay_rate=0.9996)

# %%
BATCH_SIZE = 50
opt = tf.keras.optimizers.SGD(
    learning_rate=lr,
    momentum=0.9,
    nesterov=True,
)

model.compile(optimizer=opt,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  data (InputLayer)           [(None, 32, 32, 1)]       0
#
#  conv2d (Conv2D)             (None, 32, 32, 1)         2
#
#  batch_normalization (BatchN  (None, 32, 32, 1)        4
#  ormalization)
#
#  re_lu (ReLU)                (None, 32, 32, 1)         0
#
#  conv2d_1 (Conv2D)           (None, 28, 28, 29)        754
#
#  batch_normalization_1 (Batc  (None, 28, 28, 29)       116
#  hNormalization)
#
#  re_lu_1 (ReLU)              (None, 28, 28, 29)        0
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 29)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 13, 13, 59)        15458
#
#  batch_normalization_2 (Batc  (None, 13, 13, 59)       236
#  hNormalization)
#
#  re_lu_2 (ReLU)              (None, 13, 13, 59)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 6, 59)         0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 6, 6, 74)          39368
#
#  batch_normalization_3 (Batc  (None, 6, 6, 74)         296
#  hNormalization)
#
#  re_lu_3 (ReLU)              (None, 6, 6, 74)          0
#
#  max_pooling2d_2 (MaxPooling  (None, 2, 2, 74)         0
#  2D)
#
#  flatten (Flatten)           (None, 296)               0
#
#  dense (Dense)               (None, 300)               89100
#
#  batch_normalization_4 (Batc  (None, 300)              1200
#  hNormalization)
#
#  re_lu_4 (ReLU)              (None, 300)               0
#
#  dense_1 (Dense)             (None, 300)               90300
#
#  re_lu_5 (ReLU)              (None, 300)               0
#
#  dense_2 (Dense)             (None, 43)                12943
#
#  softmax (Softmax)           (None, 43)                0
#
# =================================================================
# Total params: 249,777
# Trainable params: 248,851
# Non-trainable params: 926
# _________________________________________________________________

# %%
from tensorflow.keras.utils import to_categorical

# %%
y_train1 = to_categorical(y_train, 43)
y_validation1 = to_categorical(y_validation, 43)

# %%
hist = model.fit(X_train, 
                 y_train1, 
                 epochs=100, 
                 batch_size=BATCH_SIZE, validation_data=(X_validation, y_validation1))
# Out:
# Epoch 1/100
# 557/557 [==============================] - 60s 84ms/step - loss: 2.6971 - accuracy: 0.3305 - val_loss: 2.3370 - val_accuracy: 0.4167
# Epoch 2/100
# 557/557 [==============================] - 47s 84ms/step - loss: 1.2102 - accuracy: 0.7290 - val_loss: 0.8256 - val_accuracy: 0.8329
# Epoch 3/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.5447 - accuracy: 0.8958 - val_loss: 0.4267 - val_accuracy: 0.9233
# Epoch 4/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.3015 - accuracy: 0.9473 - val_loss: 0.2950 - val_accuracy: 0.9361
# Epoch 5/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.2004 - accuracy: 0.9659 - val_loss: 0.2027 - val_accuracy: 0.9639
# Epoch 6/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.1472 - accuracy: 0.9766 - val_loss: 0.1559 - val_accuracy: 0.9701
# Epoch 7/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.1124 - accuracy: 0.9830 - val_loss: 0.1265 - val_accuracy: 0.9779
# Epoch 8/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.0904 - accuracy: 0.9870 - val_loss: 0.1122 - val_accuracy: 0.9777
# Epoch 9/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.0738 - accuracy: 0.9898 - val_loss: 0.0783 - val_accuracy: 0.9878
# Epoch 10/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.0612 - accuracy: 0.9927 - val_loss: 0.0676 - val_accuracy: 0.9901
# Epoch 11/100
# 557/557 [==============================] - 47s 85ms/step - loss: 0.0534 - accuracy: 0.9935 - val_loss: 0.0589 - val_accuracy: 0.9914
# Epoch 12/100
# 557/557 [==============================] - 47s 85ms/step - loss: 0.0486 - accuracy: 0.9941 - val_loss: 0.0567 - val_accuracy: 0.9904
# Epoch 13/100
# 557/557 [==============================] - 47s 85ms/step - loss: 0.0394 - accuracy: 0.9964 - val_loss: 0.0507 - val_accuracy: 0.9932
# Epoch 14/100
# 557/557 [==============================] - 47s 85ms/step - loss: 0.0362 - accuracy: 0.9968 - val_loss: 0.0475 - val_accuracy: 0.9931
# Epoch 15/100
# 557/557 [==============================] - 47s 85ms/step - loss: 0.0323 - accuracy: 0.9969 - val_loss: 0.0386 - val_accuracy: 0.9945
# Epoch 16/100
# 557/557 [==============================] - 47s 85ms/step - loss: 0.0286 - accuracy: 0.9975 - val_loss: 0.0385 - val_accuracy: 0.9948
# Epoch 17/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.0269 - accuracy: 0.9977 - val_loss: 0.0547 - val_accuracy: 0.9909
# Epoch 18/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.0256 - accuracy: 0.9979 - val_loss: 0.0369 - val_accuracy: 0.9950
# Epoch 19/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.0236 - accuracy: 0.9979 - val_loss: 0.0370 - val_accuracy: 0.9945
# Epoch 20/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.0215 - accuracy: 0.9985 - val_loss: 0.0444 - val_accuracy: 0.9927
# Epoch 21/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.0192 - accuracy: 0.9987 - val_loss: 0.0311 - val_accuracy: 0.9951
# Epoch 22/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.0188 - accuracy: 0.9988 - val_loss: 0.0305 - val_accuracy: 0.9951
# Epoch 23/100
# 557/557 [==============================] - 46s 83ms/step - loss: 0.0177 - accuracy: 0.9989 - val_loss: 0.0312 - val_accuracy: 0.9948
# Epoch 24/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.0156 - accuracy: 0.9993 - val_loss: 0.0298 - val_accuracy: 0.9954
# Epoch 25/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.0154 - accuracy: 0.9991 - val_loss: 0.0389 - val_accuracy: 0.9922
# Epoch 26/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.0149 - accuracy: 0.9990 - val_loss: 0.0294 - val_accuracy: 0.9955
# Epoch 27/100
# 557/557 [==============================] - 46s 83ms/step - loss: 0.0148 - accuracy: 0.9993 - val_loss: 0.0337 - val_accuracy: 0.9941
# Epoch 28/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.0135 - accuracy: 0.9995 - val_loss: 0.0277 - val_accuracy: 0.9953
# Epoch 29/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.0149 - accuracy: 0.9989 - val_loss: 0.0278 - val_accuracy: 0.9940
# Epoch 30/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.0128 - accuracy: 0.9995 - val_loss: 0.0249 - val_accuracy: 0.9957
# Epoch 31/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.0123 - accuracy: 0.9996 - val_loss: 0.0282 - val_accuracy: 0.9945
# Epoch 32/100
# 557/557 [==============================] - 46s 83ms/step - loss: 0.0122 - accuracy: 0.9995 - val_loss: 0.0284 - val_accuracy: 0.9945
# Epoch 33/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.0107 - accuracy: 0.9998 - val_loss: 0.0251 - val_accuracy: 0.9960
# Epoch 34/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.0111 - accuracy: 0.9995 - val_loss: 0.0249 - val_accuracy: 0.9955
# Epoch 35/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.0105 - accuracy: 0.9997 - val_loss: 0.0228 - val_accuracy: 0.9961
# Epoch 36/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.0101 - accuracy: 0.9998 - val_loss: 0.0242 - val_accuracy: 0.9964
# Epoch 37/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.0103 - accuracy: 0.9996 - val_loss: 0.0233 - val_accuracy: 0.9960
# Epoch 38/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.0097 - accuracy: 0.9997 - val_loss: 0.0220 - val_accuracy: 0.9966
# Epoch 39/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.0098 - accuracy: 0.9998 - val_loss: 0.0233 - val_accuracy: 0.9961
# Epoch 40/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.0095 - accuracy: 0.9997 - val_loss: 0.0213 - val_accuracy: 0.9968
# Epoch 41/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.0092 - accuracy: 0.9999 - val_loss: 0.0225 - val_accuracy: 0.9960
# Epoch 42/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.0093 - accuracy: 0.9997 - val_loss: 0.0335 - val_accuracy: 0.9935
# Epoch 43/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.0206 - val_accuracy: 0.9970
# Epoch 44/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.0094 - accuracy: 0.9997 - val_loss: 0.0226 - val_accuracy: 0.9961
# Epoch 45/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.0087 - accuracy: 0.9998 - val_loss: 0.0208 - val_accuracy: 0.9967
# Epoch 46/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.0082 - accuracy: 0.9997 - val_loss: 0.0214 - val_accuracy: 0.9963
# Epoch 47/100
# 557/557 [==============================] - 47s 85ms/step - loss: 0.0083 - accuracy: 0.9999 - val_loss: 0.0203 - val_accuracy: 0.9971
# Epoch 48/100
# 557/557 [==============================] - 47s 85ms/step - loss: 0.0079 - accuracy: 0.9998 - val_loss: 0.0208 - val_accuracy: 0.9961
# Epoch 49/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.0080 - accuracy: 0.9999 - val_loss: 0.0229 - val_accuracy: 0.9961
# Epoch 50/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.0082 - accuracy: 0.9998 - val_loss: 0.0211 - val_accuracy: 0.9963
# Epoch 51/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.0083 - accuracy: 0.9998 - val_loss: 0.0202 - val_accuracy: 0.9971
# Epoch 52/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.0196 - val_accuracy: 0.9967
# Epoch 53/100
# 557/557 [==============================] - 47s 85ms/step - loss: 0.0076 - accuracy: 0.9998 - val_loss: 0.0199 - val_accuracy: 0.9966
# Epoch 54/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.0183 - val_accuracy: 0.9973
# Epoch 55/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.0231 - val_accuracy: 0.9955
# Epoch 56/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.0076 - accuracy: 0.9999 - val_loss: 0.0213 - val_accuracy: 0.9957
# Epoch 57/100
# 557/557 [==============================] - 47s 85ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.0196 - val_accuracy: 0.9971
# Epoch 58/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.0205 - val_accuracy: 0.9967
# Epoch 59/100
# 557/557 [==============================] - 47s 85ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.0199 - val_accuracy: 0.9964
# Epoch 60/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.0077 - accuracy: 0.9996 - val_loss: 0.0192 - val_accuracy: 0.9973
# Epoch 61/100
# 557/557 [==============================] - 47s 85ms/step - loss: 0.0069 - accuracy: 0.9999 - val_loss: 0.0239 - val_accuracy: 0.9950
# Epoch 62/100
# 557/557 [==============================] - 47s 85ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.0229 - val_accuracy: 0.9953
# Epoch 63/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.0067 - accuracy: 0.9999 - val_loss: 0.0199 - val_accuracy: 0.9966
# Epoch 64/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.0070 - accuracy: 0.9999 - val_loss: 0.0185 - val_accuracy: 0.9968
# Epoch 65/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.0184 - val_accuracy: 0.9967
# Epoch 66/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.0068 - accuracy: 0.9999 - val_loss: 0.0190 - val_accuracy: 0.9966
# Epoch 67/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.0184 - val_accuracy: 0.9970
# Epoch 68/100
# 557/557 [==============================] - 47s 85ms/step - loss: 0.0064 - accuracy: 0.9999 - val_loss: 0.0184 - val_accuracy: 0.9974
# Epoch 69/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.0066 - accuracy: 0.9998 - val_loss: 0.0179 - val_accuracy: 0.9971
# Epoch 70/100
# 557/557 [==============================] - 47s 85ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.0178 - val_accuracy: 0.9971
# Epoch 71/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.0064 - accuracy: 0.9999 - val_loss: 0.0183 - val_accuracy: 0.9970
# Epoch 72/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.0064 - accuracy: 0.9999 - val_loss: 0.0181 - val_accuracy: 0.9968
# Epoch 73/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.0181 - val_accuracy: 0.9970
# Epoch 74/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.0174 - val_accuracy: 0.9971
# Epoch 75/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.0175 - val_accuracy: 0.9970
# Epoch 76/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.0178 - val_accuracy: 0.9968
# Epoch 77/100
# 557/557 [==============================] - 46s 83ms/step - loss: 0.0059 - accuracy: 0.9999 - val_loss: 0.0208 - val_accuracy: 0.9966
# Epoch 78/100
# 557/557 [==============================] - 46s 83ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.0174 - val_accuracy: 0.9966
# Epoch 79/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.0172 - val_accuracy: 0.9971
# Epoch 80/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.0064 - accuracy: 0.9997 - val_loss: 0.0186 - val_accuracy: 0.9966
# Epoch 81/100
# 557/557 [==============================] - 46s 83ms/step - loss: 0.0066 - accuracy: 0.9998 - val_loss: 0.0200 - val_accuracy: 0.9961
# Epoch 82/100
# 557/557 [==============================] - 46s 83ms/step - loss: 0.0070 - accuracy: 0.9997 - val_loss: 0.0176 - val_accuracy: 0.9973
# Epoch 83/100
# 557/557 [==============================] - 46s 83ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.0173 - val_accuracy: 0.9964
# Epoch 84/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.0063 - accuracy: 0.9998 - val_loss: 0.0195 - val_accuracy: 0.9966
# Epoch 85/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.0173 - val_accuracy: 0.9970
# Epoch 86/100
# 557/557 [==============================] - 46s 83ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.0173 - val_accuracy: 0.9968
# Epoch 87/100
# 557/557 [==============================] - 46s 83ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.0169 - val_accuracy: 0.9973
# Epoch 88/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.0171 - val_accuracy: 0.9964
# Epoch 89/100
# 557/557 [==============================] - 47s 85ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.0172 - val_accuracy: 0.9968
# Epoch 90/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.0168 - val_accuracy: 0.9973
# Epoch 91/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.0059 - accuracy: 0.9999 - val_loss: 0.0199 - val_accuracy: 0.9963
# Epoch 92/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.0169 - val_accuracy: 0.9974
# Epoch 93/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.0169 - val_accuracy: 0.9974
# Epoch 94/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.0057 - accuracy: 0.9999 - val_loss: 0.0173 - val_accuracy: 0.9971
# Epoch 95/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.0167 - val_accuracy: 0.9976
# Epoch 96/100
# 557/557 [==============================] - 46s 83ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.0161 - val_accuracy: 0.9971
# Epoch 97/100
# 557/557 [==============================] - 46s 83ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.0171 - val_accuracy: 0.9968
# Epoch 98/100
# 557/557 [==============================] - 46s 83ms/step - loss: 0.0055 - accuracy: 0.9999 - val_loss: 0.0165 - val_accuracy: 0.9970
# Epoch 99/100
# 557/557 [==============================] - 46s 83ms/step - loss: 0.0054 - accuracy: 0.9999 - val_loss: 0.0165 - val_accuracy: 0.9970
# Epoch 100/100
# 557/557 [==============================] - 46s 83ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.0169 - val_accuracy: 0.9966

# %%
y_test1 = to_categorical(y_test, 43)

# %%
score_c = model.evaluate(X_test_norm, y_test1, verbose=0)
a = score_c[0]
b = score_c[1]*100


print(f'loss = {a:.2f}')
print(f'accuracy = {b:.2f} %')
# first training got :
# loss = 0.19
# accuracy = 95.27 %
# Out:
# loss = 0.23
# accuracy = 94.43 %

# %%
# %matplotlib inline
plt.figure(figsize=[8, 4])
epoch_range = range(0, 100)
loss = hist.history['loss']
val_loss = hist.history['val_loss']
plt.plot(epoch_range, loss, 'forestgreen', linewidth=3.0)
plt.plot(epoch_range, val_loss, 'red', ls="-", linewidth=3.0)
plt.legend(['train_loss', 'validation_loss'], fontsize=18, loc="best")
plt.xlabel("Epochs", fontsize=16, color="blue")
plt.ylabel("Loss", fontsize=16, color="blue")
plt.title("--- The Loss Curve --- ", fontsize=18, color="darkblue", fontweight="bold")
plt.grid(c="lightblue")
plt.figure(figsize=[8, 4])

epoch_range = range(0, 100) 

acc = hist.history['accuracy']
val_acc =hist.history['val_accuracy']

plt.plot(epoch_range, acc, 'b', linewidth=3.0)
plt.plot(epoch_range, val_acc, 'tomato', ls="-", linewidth=3.0)
# valid location in legend  are :  best, upper right, upper left, lower left
# lower right, right, center left, center right, lower center, upper center, center
plt.legend(['train_accuracy', 'validation_accuracy'], fontsize=18, loc="best")

plt.xlabel("Epochs", fontsize=16, c="darkblue")
plt.ylabel("Accuracy", fontsize=16, c="darkblue")
plt.title("-- The accuracy Curve -- ", fontsize=18, c="darkorchid", fontweight="bold")
plt.grid(c="pink")

# %%
tf.data.experimental.enable_debug_mode()

# %%
y_true = tf.argmax(y_test1, axis = 1)
predicted_classes = np.argmax(model.predict(X_test_norm), axis=-1)

# %%
cm = confusion_matrix(y_true, predicted_classes)
# accuracies = cm/cm.sum(1)

# %%
# %matplotlib inline
plt.figure(figsize=(22,15))
annot_kws={'fontsize':16, 
           'fontstyle':'italic',
           'color':"azure"}
sns.heatmap(cm,
            linewidths=0.7,
            color="pink",
            annot = True, 
            cbar = False, 
            cmap='Dark2_r', 
            fmt="d", 
            # xticklabels=signs, 
            # yticklabels=signs,
            annot_kws=annot_kws)

plt.xticks(range(len(signs)), signs, rotation=90, c="darkgreen")
plt.yticks(range(len(signs)), signs, rotation=0, c="mediumblue")
plt.ylabel('Actual label', c="mediumblue")
plt.xlabel('Predicted label', c="darkgreen")
plt.title('Confusion Matrix', c="darkblue")
# Out:
# Text(0.5, 1.0, 'Confusion Matrix')

# %%
# We will use the test dataset to test trained model's prediction 
# of instances that it has never seen during training.
print("Test Set\t= {} samples".format(len(X_test)))
print('n_classes\t= {}'.format(n_classes))
X_test.shape
# Out:
# Test Set	= 12630 samples
# n_classes	= 43
# (12630, 32, 32, 3)

# %%
# we have also our xtest normalized above and ytest one hot encoded
print("Test Set Normalized : {} samples".format(len(X_test_norm)))
print('labels encoded     : {}'.format(len(y_test1)))
X_test_norm.shape
X_test_norm[1][1][:5]
# Out:
# Test Set Normalized : 12630 samples
# labels encoded     : 12630
# array([[-0.51822917],
#        [-0.36979167],
#        [-0.3828125 ],
#        [-0.34375   ],
#        [-0.4140625 ]])

# %%
performance = model.evaluate(X_test_norm, y_test1)
dict(zip(model.metrics_names, performance))
# Out:
# 395/395 [==============================] - 14s 35ms/step - loss: 0.2296 - accuracy: 0.9443
# {'accuracy': 0.9442597031593323, 'loss': 0.22957952320575714}

# %%
MODEL_NAME = "ResNet34_sgd.h5"
model.save(MODEL_NAME)

# %%
# reconstructed= keras.models.load_model("ResNet_34_improved.h5")

# %%
from itertools import cycle, islice

# %%
classwise_acc = cm.diagonal()/cm.sum(axis=1) * 100 
cls_acc = pd.DataFrame({'Class_Label':[signs[i] for i in range(43)], 'Accuracy': classwise_acc.tolist()}, columns = ['Class_Label', 'Accuracy'])

cls_acc.style.format({"Accuracy": "{:,.2f}",}).hide_index().bar(subset=["Accuracy"])

cam = sns.light_palette("#2ecc71", as_cmap=True)
cls_acc.style.background_gradient(cmap=cam).set_precision(2)
# Out:
# <style  type="text/css" >
# #T_15c29afe_59bf_11ec_9a23_0242ac1c0002row0_col1,#T_15c29afe_59bf_11ec_9a23_0242ac1c0002row29_col1{
#             background-color:  #60d692;
#             color:  #000000;
#         }#T_15c29afe_59bf_11ec_9a23_0242ac1c0002row1_col1,#T_15c29afe_59bf_11ec_9a23_0242ac1c0002row8_col1{
#             background-color:  #3bcf7a;
#             color:  #000000;
#         }#T_15c29afe_59bf_11ec_9a23_0242ac1c0002row2_col1{
#             background-color:  #35ce76;
#             color:  #000000;
#         }#T_15c29afe_59bf_11ec_9a23_0242ac1c0002row3_col1{
#             background-color:  #3fcf7c;
#             color:  #000000;
#         }#T_15c29afe_59bf_11ec_9a23_0242ac1c0002row4_col1{
#             background-color:  #3bcf79;
#             color:  #000000;
#         }#T_15c29afe_59bf_11ec_9a23_0242ac1c0002row5_col1{
#             background-color:  #45d180;
#             color:  #000000;
#         }#T_15c29afe_59bf_11ec_9a23_0242ac1c0002row6_col1,#T_15c29afe_59bf_11ec_9a23_0242ac1c0002row22_col1{
#             background-color:  #6dd99a;
#             color:  #000000;
#         }#T_15c29afe_59bf_11ec_9a23_0242ac1c0002row7_col1,#T_15c29afe_59bf_11ec_9a23_0242ac1c0002row36_col1{
#             background-color:  #54d48a;
#             color:  #000000;
#         }#T_15c29afe_59bf_11ec_9a23_0242ac1c0002row9_col1{
#             background-color:  #32cd74;
#             color:  #000000;
#         }#T_15c29afe_59bf_11ec_9a23_0242ac1c0002row10_col1{
#             background-color:  #32cd73;
#             color:  #000000;
#         }#T_15c29afe_59bf_11ec_9a23_0242ac1c0002row11_col1{
#             background-color:  #4cd284;
#             color:  #000000;
#         }#T_15c29afe_59bf_11ec_9a23_0242ac1c0002row12_col1,#T_15c29afe_59bf_11ec_9a23_0242ac1c0002row31_col1{
#             background-color:  #30cc72;
#             color:  #000000;
#         }#T_15c29afe_59bf_11ec_9a23_0242ac1c0002row13_col1{
#             background-color:  #2fcc71;
#             color:  #000000;
#         }#T_15c29afe_59bf_11ec_9a23_0242ac1c0002row14_col1{
#             background-color:  #35cd75;
#             color:  #000000;
#         }#T_15c29afe_59bf_11ec_9a23_0242ac1c0002row15_col1,#T_15c29afe_59bf_11ec_9a23_0242ac1c0002row16_col1,#T_15c29afe_59bf_11ec_9a23_0242ac1c0002row32_col1{
#             background-color:  #2ecc71;
#             color:  #000000;
#         }#T_15c29afe_59bf_11ec_9a23_0242ac1c0002row17_col1{
#             background-color:  #4ad283;
#             color:  #000000;
#         }#T_15c29afe_59bf_11ec_9a23_0242ac1c0002row18_col1{
#             background-color:  #63d794;
#             color:  #000000;
#         }#T_15c29afe_59bf_11ec_9a23_0242ac1c0002row19_col1,#T_15c29afe_59bf_11ec_9a23_0242ac1c0002row37_col1{
#             background-color:  #34cd75;
#             color:  #000000;
#         }#T_15c29afe_59bf_11ec_9a23_0242ac1c0002row20_col1,#T_15c29afe_59bf_11ec_9a23_0242ac1c0002row26_col1{
#             background-color:  #64d794;
#             color:  #000000;
#         }#T_15c29afe_59bf_11ec_9a23_0242ac1c0002row21_col1{
#             background-color:  #b8e8cc;
#             color:  #000000;
#         }#T_15c29afe_59bf_11ec_9a23_0242ac1c0002row23_col1{
#             background-color:  #38ce77;
#             color:  #000000;
#         }#T_15c29afe_59bf_11ec_9a23_0242ac1c0002row24_col1{
#             background-color:  #68d897;
#             color:  #000000;
#         }#T_15c29afe_59bf_11ec_9a23_0242ac1c0002row25_col1,#T_15c29afe_59bf_11ec_9a23_0242ac1c0002row28_col1{
#             background-color:  #44d180;
#             color:  #000000;
#         }#T_15c29afe_59bf_11ec_9a23_0242ac1c0002row27_col1{
#             background-color:  #ebf3ec;
#             color:  #000000;
#         }#T_15c29afe_59bf_11ec_9a23_0242ac1c0002row30_col1{
#             background-color:  #88dfac;
#             color:  #000000;
#         }#T_15c29afe_59bf_11ec_9a23_0242ac1c0002row33_col1{
#             background-color:  #38ce78;
#             color:  #000000;
#         }#T_15c29afe_59bf_11ec_9a23_0242ac1c0002row34_col1{
#             background-color:  #31cd73;
#             color:  #000000;
#         }#T_15c29afe_59bf_11ec_9a23_0242ac1c0002row35_col1{
#             background-color:  #43d07f;
#             color:  #000000;
#         }#T_15c29afe_59bf_11ec_9a23_0242ac1c0002row38_col1{
#             background-color:  #36ce76;
#             color:  #000000;
#         }#T_15c29afe_59bf_11ec_9a23_0242ac1c0002row39_col1{
#             background-color:  #4bd284;
#             color:  #000000;
#         }#T_15c29afe_59bf_11ec_9a23_0242ac1c0002row40_col1{
#             background-color:  #93e1b3;
#             color:  #000000;
#         }#T_15c29afe_59bf_11ec_9a23_0242ac1c0002row41_col1{
#             background-color:  #b2e7c8;
#             color:  #000000;
#         }#T_15c29afe_59bf_11ec_9a23_0242ac1c0002row42_col1{
#             background-color:  #4fd387;
#             color:  #000000;
#         }</style><table id="T_15c29afe_59bf_11ec_9a23_0242ac1c0002" class="dataframe"><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Class_Label</th>        <th class="col_heading level0 col1" >Accuracy</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_15c29afe_59bf_11ec_9a23_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_15c29afe_59bf_11ec_9a23_0242ac1c0002row0_col0" class="data row0 col0" >Speed limit (20km/h)</td>
#                         <td id="T_15c29afe_59bf_11ec_9a23_0242ac1c0002row0_col1" class="data row0 col1" >86.67</td>
#             </tr>
#             <tr>
#                         <th id="T_15c29afe_59bf_11ec_9a23_0242ac1c0002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_15c29afe_59bf_11ec_9a23_0242ac1c0002row1_col0" class="data row1 col0" >Speed limit (30km/h)</td>
#                         <td id="T_15c29afe_59bf_11ec_9a23_0242ac1c0002row1_col1" class="data row1 col1" >96.39</td>
#             </tr>
#             <tr>
#                         <th id="T_15c29afe_59bf_11ec_9a23_0242ac1c0002level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_15c29afe_59bf_11ec_9a23_0242ac1c0002row2_col0" class="data row2 col0" >Speed limit (50km/h)</td>
#                         <td id="T_15c29afe_59bf_11ec_9a23_0242ac1c0002row2_col1" class="data row2 col1" >98.00</td>
#             </tr>
#             <tr>
#                         <th id="T_15c29afe_59bf_11ec_9a23_0242ac1c0002level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_15c29afe_59bf_11ec_9a23_0242ac1c0002row3_col0" class="data row3 col0" >Speed limit (60km/h)</td>
#                         <td id="T_15c29afe_59bf_11ec_9a23_0242ac1c0002row3_col1" class="data row3 col1" >95.33</td>
#             </tr>
#             <tr>
#                         <th id="T_15c29afe_59bf_11ec_9a23_0242ac1c0002level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_15c29afe_59bf_11ec_9a23_0242ac1c0002row4_col0" class="data row4 col0" >Speed limit (70km/h)</td>
#                         <td id="T_15c29afe_59bf_11ec_9a23_0242ac1c0002row4_col1" class="data row4 col1" >96.67</td>
#             </tr>
#             <tr>
#                         <th id="T_15c29afe_59bf_11ec_9a23_0242ac1c0002level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_15c29afe_59bf_11ec_9a23_0242ac1c0002row5_col0" class="data row5 col0" >Speed limit (80km/h)</td>
#                         <td id="T_15c29afe_59bf_11ec_9a23_0242ac1c0002row5_col1" class="data row5 col1" >93.81</td>
#             </tr>
#             <tr>
#                         <th id="T_15c29afe_59bf_11ec_9a23_0242ac1c0002level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_15c29afe_59bf_11ec_9a23_0242ac1c0002row6_col0" class="data row6 col0" >End of speed limit (80km/h)</td>
#                         <td id="T_15c29afe_59bf_11ec_9a23_0242ac1c0002row6_col1" class="data row6 col1" >83.33</td>
#             </tr>
#             <tr>
#                         <th id="T_15c29afe_59bf_11ec_9a23_0242ac1c0002level0_row7" class=

# %%
X_test_norm.shape
y_test.shape
# Out:
# (12630,)

# %%
y_test[1]
# Out:
# 1

# %%
# Pick 10 random images
sample_indexes = random.sample(range(len(X_test_norm)), 10)
sample_indexes
sample_images = [X_test_norm[i] for i in sample_indexes]
sample_images[1][1][0]
labels = np.argmax(y_test1, axis=1)
sample_labels = [labels[i] for i in sample_indexes]
sample_labels
# Out:
# [37, 4, 14, 40, 8, 18, 25, 26, 36, 2]

# %%
y_pred = model.predict(X_test_norm)
y_pred[1]
# Out:
# array([6.42738496e-06, 9.99582231e-01, 1.04629153e-05, 4.11468148e-09,
#        3.93515016e-04, 1.85299780e-06, 1.05764791e-07, 2.48037715e-08,
#        1.54537645e-07, 1.35786166e-07, 1.94423078e-09, 2.07265387e-08,
#        7.83454812e-09, 5.83330184e-09, 2.87372846e-08, 9.53441372e-07,
#        2.93008888e-08, 2.38523601e-09, 1.00417583e-06, 5.63039691e-07,
#        2.33467828e-10, 8.82467877e-09, 8.17884982e-10, 1.51285137e-10,
#        4.35730328e-07, 2.38401698e-09, 5.60138574e-07, 4.05686194e-07,
#        9.76024039e-10, 6.91167713e-07, 3.20552540e-09, 4.09947774e-08,
#        2.00553139e-08, 9.29263688e-09, 8.13436358e-08, 1.32341027e-08,
#        1.18100495e-07, 7.19872020e-08, 5.64261571e-09, 3.95827326e-09,
#        3.67525317e-08, 2.22005525e-09, 2.04511430e-08], dtype=float32)

# %%
predicted = model.predict(X_test_norm[sample_indexes].reshape(10, 32, 32, 1))
print(sample_labels[0])
print(predicted_classes)
# Out:
# 37
# [16  1 38 ...  3  7 10]

# %%
SMALL_SIZE = 8
MEDIUM_SIZE = 10
BIGGER_SIZE = 14

plt.rc('font', size=BIGGER_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

# %%
# color='green' if np.argmax(y_test1[r]) == np.argmax(model.predict(X_test_norm[r].reshape(1, 32, 32, 1))) else 'red'

# %%
# plt.rcParams['font.size'] = 11
fig2, axes2 = plt.subplots(5,5, figsize=(18,10))
for i,ax2 in enumerate(axes2.flat):
    r = np.random.randint(X_test_norm.shape[0])
    ax2.imshow(X_test[r].astype('uint8'))
    ax2.grid(False)
    ax2.axis('off')
    color='green' if np.argmax(y_test1[r]) == np.argmax(model.predict(X_test_norm[r].reshape(1, 32, 32, 1))) else 'red'
    ax2.set_title('Original: {} Predicted: {}'.format(np.argmax(y_test1[r]), 
                                                     np.argmax(model.predict(X_test_norm[r].reshape(1, 32, 32, 1)))),color=color)
plt.show()

# %% [markdown]
# A validation set can be used to assess how well the model is performing. A low accuracy on the training and validation
# sets imply underfitting. A high accuracy on the training set but low accuracy on the validation set implies overfitting.

# %% [markdown]
# - In this case study, we want to classify images of traffic signs using deep Convolutional Neural Networks (CNNs).
# - The dataset consists of 43 different classes of images.
# - Classes are as listed below:
#   - 0 = Speed limit (20km/h)
#   - 1 = Speed limit (30km/h)
#   - 2 = Speed limit (50km/h)
#   - 3 = Speed limit (60km/h)
#   - 4 = Speed limit (70km/h)
#   - 5 = Speed limit (80km/h)
#   - 6 = End of speed limit (80km/h)
#   - 7 = Speed limit (100km/h)
#   - 8 = Speed limit (120km/h)
#   - 9 = No passing
#   - 10 = No passing for vehicles over 3.5 metric tons
#   - 11 = Right-of-way at the next intersection
#   - 12 = Priority road
#   - 13 = Yield
#   - 14 = Stop
#   - 15 = No vehicles
#   - 16 = Vehicles over 3.5 metric tons prohibited
#   - 17 = No entry
#   - 18 = General caution
#   - 19 = Dangerous curve to the left
#   - 20 = Dangerous curve to the right
#   - 21 = Double curve
#   - 22 = Bumpy road
#   - 23 = Slippery road
#   - 24 = Road narrows on the right
#   - 25 = Road work
#   - 26 = Traffic signals
#   - 27 = Pedestrians
#   - 28 = Children crossing
#   - 29 = Bicycles crossing
#   - 30 = Beware of ice/snow
#   - 31 = Wild animals crossing
#   - 32 = End of all speed and passing limits
#   - 33 = Turn right ahead
#   - 34 = Turn left ahead
#   - 35 = Ahead only
#   - 36 = Go straight or right
#   - 37 = Go straight or left
#   - 38 = Keep right
#   - 39 = Keep left
#   - 40 = Roundabout mandatory
#   - 41 = End of no passing
#   - 42 = End of no passing by vehicles over 3.5 metric tons
#
# - Citation
# J. Stallkamp, M. Schlipsing, J. Salmen, and C. Igel. The German Traffic Sign Recognition Benchmark: A multi-class classification competition. In Proceedings of the IEEE International Joint Conference on Neural Networks, pages 1453–1460. 2011.
# @inproceedings{Stallkamp-IJCNN-2011, author = {Johannes Stallkamp and Marc Schlipsing and Jan Salmen and Christian Igel}, booktitle = {IEEE International Joint Conference on Neural Networks}, title = {The {G}erman {T}raffic {S}ign {R}ecognition {B}enchmark: A multi-class classification competition}, year = {2011}, pages = {1453--1460} }
